# %%
# Installing Backtesting modules
# !pip install backtesting

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the necessary modules
import backtesting
from backtesting import Backtest, Strategy
from backtesting.lib import crossover
from backtesting.test import SMA, GOOG
backtesting.set_bokeh_output(notebook=False)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a5039bba-5563-4151-87c6-884b70319012">Loading BokehJS ...</span>
#     </div>

# %%
class TechnicalSMAStrategy(Strategy):

    def init(self):
        price = self.data.Close
        self.ma1 = self.I(SMA, price, 10)
        self.ma2 = self.I(SMA, price, 20)

    def next(self):
        if crossover(self.ma1, self.ma2):
            self.buy()
        elif crossover(self.ma2, self.ma1):
            self.sell()

backtest = Backtest(GOOG, TechnicalSMAStrategy, commission=0.002, exclusive_orders=True)
stats = backtest.run()
print(stats)
# Out:
# Start                     2004-08-19 00:00:00
# End                       2013-03-01 00:00:00
# Duration                   3116 days 00:00:00
# Exposure Time [%]                   97.067039
# Equity Final [$]                  68221.96986
# Equity Peak [$]                   68991.21986
# Return [%]                         582.219699
# Buy & Hold Return [%]              703.458242
# Return (Ann.) [%]                   25.266427
# Volatility (Ann.) [%]               38.383008
# Sharpe Ratio                         0.658271
# Sortino Ratio                        1.288779
# Calmar Ratio                         0.763748
# Max. Drawdown [%]                  -33.082172
# Avg. Drawdown [%]                   -5.581506
# Max. Drawdown Duration      688 days 00:00:00
# Avg. Drawdown Duration       41 days 00:00:00
# # Trades                                   94
# Win Rate [%]                        54.255319
# Best Trade [%]                       57.11931
# Worst Trade [%]                    -16.629898
# Avg. Trade [%]                       2.074326
# Max. Trade Duration         121 days 00:00:00
# Avg. Trade Duration          33 days 00:00:00
# Profit Factor                        2.190805
# Expectancy [%]                       2.606294
# SQN                                  1.990216
# _strategy                 TechnicalSMAStra...
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %%
# Plotting the backtest result
import warnings
warnings.filterwarnings('ignore')
backtest.plot()
# Out:
# GridPlot(id='p1325', ...)
